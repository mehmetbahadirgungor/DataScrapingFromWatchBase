# %%
import pandas as pd
data = pd.read_csv("watchesoriginal.csv")
# Out:
# C:\Users\bahad\AppData\Local\Temp\ipykernel_13860\1596383200.py:2: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("watchesoriginal.csv")

# %%
data
# Out:
#        Unnamed: 0.1  Unnamed: 0             Brand   Family  \
# 0                 0           0  A. Lange & Söhne     1815
# 1                 1           1  A. Lange & Söhne     1815
# 2                 2           2  A. Lange & Söhne     1815
# 3                 3           3  A. Lange & Söhne     1815
# 4                 4           4  A. Lange & Söhne     1815
# ...             ...         ...               ...      ...
# 37196         37196       37196            Zenith  Revival
# 37197         37197       37197            Zenith  Revival
# 37198         37198       37198            Zenith  Revival
# 37199         37199       37199            Zenith  Revival
# 37200         37200       37200            Zenith  Revival
#
#                              Reference  \
# 0                              239.050
# 1      730.032\n(aka: 730032f, 730032)
# 2                              206.029
# 3               414.028\n(aka: 414028)
# 4                              206.025
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37201 entries, 0 to 37200
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  37201 non-null  int64
#  1   Unnamed: 0    37201 non-null  int64
#  2   Brand         37200 non-null  object
#  3   Family        37199 non-null  object
#  4   Reference     37200 non-null  object
#  5   Name          37200 non-null  object
#  6   Movement      37062 non-null  object
#  7   Produced      22648 non-null  object
#  8   Limited       37200 non-null  object
#  9   Material      31070 non-null  object
#  10  Glass         36927 non-null  object
#  11  Back          37027 non-null  object
#  12  Shape         36781 non-null  object
#  13  Diameter      37084 non-null  object
#  14  Height        19624 non-null  object
#  15  Lug Width     23057 non-null  object
#  16  Color         36973 non-null  object
#  17  Indexes       36499 non-null  object
# ...
